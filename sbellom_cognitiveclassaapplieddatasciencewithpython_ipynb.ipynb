# %% [markdown]
# # Applied Data Science with Python
#
# Name:
# Santiago Bello Moreno
#
# UNAL User:
# sbellom
#
# LinkedIn:
# https://www.linkedin.com/in/santiago-bello-02b2a1245/?skipRedirect=true

# %% [markdown]
# ![linkedin_screenshot.png](data:image/png;base64,...)
